# %%
# ニューラルネットワーク
## ステップ関数の実装
### 複数入力、複数出力

import numpy as np

def step_func(x):
    y = x > 0
    return y.astype(np.int)

# %%
# # ステップ関数の可視化

# import matplotlib.pyplot as plt 

# x = np.arange(-5.0, 5.0, 0.1)
# y = step_func(x)

# plt.plot(x, y)

# plt.show()

# %%
# シグモイド関数

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# シグモイド関数の図示

y = sigmoid(x)

plt.plot(x, y)

plt.show()
